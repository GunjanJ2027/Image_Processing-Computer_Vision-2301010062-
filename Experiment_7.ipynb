# %% [markdown]
# <a href="https://colab.research.google.com/github/GunjanJ2027/Image_Processing-Computer_Vision-2301010062-/blob/main/Experiment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np

# %%
img= cv2.imread('/content/ipcv image.jpeg')

# %%
rows, cols= img.shape[:2]

# %%
M_trans = np.float32([[1,0,50], [0,1,50]])

# %%
translated = cv2.warpAffine(img, M_trans, (cols, rows))

# %%
cv2.imwrite("translation.jpg", translated)
# Out:
# True

# %%
scaled = cv2.resize(img, None, fx= 0.5, fy = 0.5)

# %%
M_rot = cv2.getRotationMatrix2D((cols/2, rows/2), 60,1)

# %%
rotated = cv2.warpAffine(img, M_rot, (cols, rows))

# %%
cv2.imwrite("rotated.jpg", rotated)
# Out:
# True
